# %%
# Script to show an individuals Climbed or Unclimbed Munros

import pandas as pd
import folium

# %%
# !pip show folium
# Out:
# Name: folium
# Version: 0.18.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: branca, jinja2, numpy, requests, xyzservices
# Required-by:

# %%
path_jo = '/Users/gordonwatt/code/dev/munro/data/Jo.csv'
path_gordon = '/Users/gordonwatt/code/dev/munro/data/Gordon.csv'
path_alan = '/Users/gordonwatt/code/dev/munro/data/Alan_Dunmur.csv'
path_ian = '/Users/gordonwatt/code/dev/munro/data/Ian_Sharp.csv'
path_iain = '/Users/gordonwatt/code/dev/munro/data/Iain_Young.csv'
path_freya = '/Users/gordonwatt/code/dev/munro/data/freya.csv'


# Load the CSV file
file1 = pd.read_csv(path_gordon, encoding='utf-8')

# Drop rows where ascents = true (we only want unclimbed hills)
file1_all = file1
file1_remaining = file1[file1['Ascent'].isna()]
file1_climbed = file1[file1['Ascent'].notna()]

# Draw a map

# Create a map centered around the mean latitude and longitude
center_lat = file1_remaining['Latitude'].mean()
center_lon = file1_remaining['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# Add markers with name labels next to each point
for idx, row in file1_remaining.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='blue', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    
for idx, row in file1_climbed.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='green', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    

# Display the map in a Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e4bd13258b209dac0e0016ea53c1bb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e4bd13258b209dac0e0016ea53c1bb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e4bd13258b209dac0e0016ea53c1bb4 = L.map(
#                 &quot;map_4e4bd13258b209dac0e0016ea53c1bb4&quot;,
#                 {
#                     center: [56.94503893, -4.951553109999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f7aea712ca61abeb57cb6e6671be25c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8f7aea712ca61abeb57cb6e6671be25c.addTo(map_4e4bd13258b209dac0e0016ea53c1bb4);
#
#
#             var marker_7a7147bb9e5824cc05cd708129fa1c0a = L.marker(
#                 [57.184186, -5.154837],
#                 {}
#             ).addTo(map_4e4bd13258b209dac0e0016ea53c1bb4);
#
#
#             var icon_f1d2b71467de8879fed012a90eb7a38c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a7147bb9e5824cc05cd708129fa1c0a.setIcon(icon_f1d2b71467de8879fed012a90eb7a38c);
#
#
#         var popup_20a9d84a30b2614b7a2633a1fd00440e = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_a3591ca0a95840f4511313fbf0325a1f = $(`&lt;div id=&quot;html_a3591ca0a95840f4511313fbf0325a1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Chraileag&lt;/div&gt;`)[0];
#                 popup_20a9d84a30b2614b7a2633a1fd00440e.setContent(html_a3591ca0a95840f4511313fbf0325a1f);
#
#
#
#         marker_7a7147bb9e5824cc05cd708129fa1c0a.bindPopup(popup_20a9d84a30b2614b7a2633a1fd00440e)
#         ;
#
#
#
#
#             var marker_7286c2534e4ccd07d7ac7bc8ce35885f = L.marker(
#                 [57.255081, -5.303686],
#                 {}
#             ).addTo(map_4e4bd13258b209dac0e0016ea53c1bb4);
#
#
#             var icon_5bf1852b6c75228dafd7d545abf0033f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7286c2534e4ccd07d7ac7bc8ce35885f.setIcon(icon_5bf1852b6c75228dafd7d545abf0033f);
#
#
#         var popup_a7d8fd66909b38da0e6ca8c71858316b = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_36017902804debe86ea1bd9e976a3f87 = $(`&lt;div id=&quot;html_36017902804debe86ea1bd9e976a3f87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Ghlas-bheinn&lt;/div&gt;`)[0];
#                 popup_a7d8fd66909b38da0e6ca8c71858316b.setContent(html_36017902804debe86ea1bd9e976a3f87);
#
#
#
#         marker_7286c2534e4ccd07d7ac7bc8ce35885f.bindPopup(popup_a7d8fd66909b38da0e6ca8c71858316b)
#         ;
#
#
#
#
#             var marker_e444767742568fca32037fbf592a9160 = L.marker(
#                 [57.719644, -5.346737],
#                 {}
#             ).addTo(map_4e4bd13258b209dac0e0016ea53c1bb4);
#
#
#             var icon_18777d7e73b8578a329bed923f15a1ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e444767742568fca32037fbf592a9160.setIcon(icon_18777d7e73b8578a329bed923f15a1ec);
#
#
#         var popup_3fe9751f56d29720f6ee729f63691582 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_faffe63a7d8ae5e2722830677713afbc = $(`&lt;div id=&quot;html_faffe63a7d8ae5e2722830677713afbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Mhaighdean&lt;/div&gt;`)[0];
#                 popup_3fe9751f56d29720f6ee729f63691582.setContent(html_faffe63a7d8ae5e2722830677713afbc);
#
#
#
#         marker_e444767742568fca32037fbf592a9160.bindPopup(popup_3fe9751f56d29720f6ee729f63691582)
#         ;
#
#
#
#
#             var marker_43305594b79c60541e41555775aba331 = L.marker(
#                 [57.667625, -4.949498],
#                 {}
#             ).addTo(map_4e4bd13258b209dac0e0016ea53c1bb4);
#
#
#             var icon_454efdd4b477896061ecf77e36cc56f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &

# %%
# save map
m.save("/Users/gordonwatt/code/dev/munro/output/grw.html")
