# %%
# Script to show an individuals Climbed or Unclimbed Munros

import pandas as pd
import folium

# %%
# !pip show folium
# Out:
# Name: folium
# Version: 0.18.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: branca, jinja2, numpy, requests, xyzservices
# Required-by:

# %%
path_jo = '/Users/gordonwatt/code/dev/munro/data/Jo.csv'
path_gordon = '/Users/gordonwatt/code/dev/munro/data/Gordon.csv'
path_alan = '/Users/gordonwatt/code/dev/munro/data/Alan_Dunmur.csv'
path_ian = '/Users/gordonwatt/code/dev/munro/data/Ian_Sharp.csv'
path_iain = '/Users/gordonwatt/code/dev/munro/data/Iain_Young.csv'
path_freya = '/Users/gordonwatt/code/dev/munro/data/freya.csv'


# Load the CSV file
file1 = pd.read_csv(path_gordon, encoding='utf-8')

# Drop rows where ascents = true (we only want unclimbed hills)
file1_all = file1
file1_remaining = file1[file1['Ascent'].isna()]
file1_climbed = file1[file1['Ascent'].notna()]

# Draw a map

# Create a map centered around the mean latitude and longitude
center_lat = file1_remaining['Latitude'].mean()
center_lon = file1_remaining['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# Add markers with name labels next to each point
for idx, row in file1_remaining.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='blue', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    
for idx, row in file1_climbed.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='green', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    

# Display the map in a Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_585ece25001c9a349b8698a6bb1ee8e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_585ece25001c9a349b8698a6bb1ee8e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_585ece25001c9a349b8698a6bb1ee8e5 = L.map(
#                 &quot;map_585ece25001c9a349b8698a6bb1ee8e5&quot;,
#                 {
#                     center: [56.94503893, -4.951553109999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66a75c3194b303ed0ad35d83ae42f619 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_66a75c3194b303ed0ad35d83ae42f619.addTo(map_585ece25001c9a349b8698a6bb1ee8e5);
#
#
#             var marker_c69ba553d6d53e3526f0422358c9d41c = L.marker(
#                 [57.184186, -5.154837],
#                 {}
#             ).addTo(map_585ece25001c9a349b8698a6bb1ee8e5);
#
#
#             var icon_500e7b5611b69a2a52bee04122e82d16 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c69ba553d6d53e3526f0422358c9d41c.setIcon(icon_500e7b5611b69a2a52bee04122e82d16);
#
#
#         var popup_11a9712fdcf4967f59ce462d0cce85b1 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_febb45dc7335233771769bd5c18c75de = $(`&lt;div id=&quot;html_febb45dc7335233771769bd5c18c75de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Chraileag&lt;/div&gt;`)[0];
#                 popup_11a9712fdcf4967f59ce462d0cce85b1.setContent(html_febb45dc7335233771769bd5c18c75de);
#
#
#
#         marker_c69ba553d6d53e3526f0422358c9d41c.bindPopup(popup_11a9712fdcf4967f59ce462d0cce85b1)
#         ;
#
#
#
#
#             var marker_fe714c2b09137a389296560eecc66aa4 = L.marker(
#                 [57.255081, -5.303686],
#                 {}
#             ).addTo(map_585ece25001c9a349b8698a6bb1ee8e5);
#
#
#             var icon_833bd1f70fed56d3a8ba5fb3393c37d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe714c2b09137a389296560eecc66aa4.setIcon(icon_833bd1f70fed56d3a8ba5fb3393c37d0);
#
#
#         var popup_8100a136aa9d1c0927dca19451e4242f = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_704eab5a4f22a5b72412fc0860882e7e = $(`&lt;div id=&quot;html_704eab5a4f22a5b72412fc0860882e7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Ghlas-bheinn&lt;/div&gt;`)[0];
#                 popup_8100a136aa9d1c0927dca19451e4242f.setContent(html_704eab5a4f22a5b72412fc0860882e7e);
#
#
#
#         marker_fe714c2b09137a389296560eecc66aa4.bindPopup(popup_8100a136aa9d1c0927dca19451e4242f)
#         ;
#
#
#
#
#             var marker_60ba6a20d376b593a591ed3225d6e911 = L.marker(
#                 [57.719644, -5.346737],
#                 {}
#             ).addTo(map_585ece25001c9a349b8698a6bb1ee8e5);
#
#
#             var icon_3f1b3356288ef2022117c4b726ab2a41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_60ba6a20d376b593a591ed3225d6e911.setIcon(icon_3f1b3356288ef2022117c4b726ab2a41);
#
#
#         var popup_d2fc4b5f184e20051543cb1cbd23fd71 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_d61c58a4097b12661aeb057354ecb106 = $(`&lt;div id=&quot;html_d61c58a4097b12661aeb057354ecb106&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Mhaighdean&lt;/div&gt;`)[0];
#                 popup_d2fc4b5f184e20051543cb1cbd23fd71.setContent(html_d61c58a4097b12661aeb057354ecb106);
#
#
#
#         marker_60ba6a20d376b593a591ed3225d6e911.bindPopup(popup_d2fc4b5f184e20051543cb1cbd23fd71)
#         ;
#
#
#
#
#             var marker_8b4d869ee7f767006914083c33950419 = L.marker(
#                 [57.667625, -4.949498],
#                 {}
#             ).addTo(map_585ece25001c9a349b8698a6bb1ee8e5);
#
#
#             var icon_844ac42c38c0f2a460f31f0d489d047b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &

# %%
# save map
m.save("/Users/gordonwatt/code/dev/munro/output/grw.html")
