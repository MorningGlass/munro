# %%
# Script to show an individuals Climbed or Unclimbed Munros

import pandas as pd
import folium

# %%
# !pip show folium
# Out:
# Name: folium
# Version: 0.18.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: branca, jinja2, numpy, requests, xyzservices
# Required-by:

# %%
path_jo = '/Users/gordonwatt/code/dev/munro/data/Jo.csv'
path_gordon = '/Users/gordonwatt/code/dev/munro/data/Gordon.csv'
path_alan = '/Users/gordonwatt/code/dev/munro/data/Alan_Dunmur.csv'
path_ian = '/Users/gordonwatt/code/dev/munro/data/Ian_Sharp.csv'
path_iain = '/Users/gordonwatt/code/dev/munro/data/Iain_Young.csv'
path_freya = '/Users/gordonwatt/code/dev/munro/data/freya.csv'


# Load the CSV file
file1 = pd.read_csv(path_freya, encoding='utf-8')

# Drop rows where ascents = true (we only want unclimbed hills)
file1_all = file1
file1_remaining = file1[file1['Ascent'].isna()]
file1_climbed = file1[file1['Ascent'].notna()]

# Draw a map

# Create a map centered around the mean latitude and longitude
center_lat = file1_remaining['Latitude'].mean()
center_lon = file1_remaining['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# Add markers with name labels next to each point
for idx, row in file1_remaining.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='blue', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    
for idx, row in file1_climbed.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='green', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    

# Display the map in a Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_529a1828d72ecd7268c7e512b1327211 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_529a1828d72ecd7268c7e512b1327211&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_529a1828d72ecd7268c7e512b1327211 = L.map(
#                 &quot;map_529a1828d72ecd7268c7e512b1327211&quot;,
#                 {
#                     center: [56.94561889320388, -4.940373582524272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79e052da3926255f464b9f1188e32a9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_79e052da3926255f464b9f1188e32a9f.addTo(map_529a1828d72ecd7268c7e512b1327211);
#
#
#             var marker_e252ff40167404064c2b69a86c9d9ef5 = L.marker(
#                 [56.39023, -4.83563],
#                 {}
#             ).addTo(map_529a1828d72ecd7268c7e512b1327211);
#
#
#             var icon_015c35f42e373ab52c5f82e232a46130 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e252ff40167404064c2b69a86c9d9ef5.setIcon(icon_015c35f42e373ab52c5f82e232a46130);
#
#
#         var popup_06b7526835cb4d5f4ac25f413e8e2fc0 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_8bf9269217b106e2c76e6bd7a07e6897 = $(`&lt;div id=&quot;html_8bf9269217b106e2c76e6bd7a07e6897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn a&#x27; Chleibh&lt;/div&gt;`)[0];
#                 popup_06b7526835cb4d5f4ac25f413e8e2fc0.setContent(html_8bf9269217b106e2c76e6bd7a07e6897);
#
#
#
#         marker_e252ff40167404064c2b69a86c9d9ef5.bindPopup(popup_06b7526835cb4d5f4ac25f413e8e2fc0)
#         ;
#
#
#
#
#             var marker_504044c0721bd3a8d2712aa97c84ece6 = L.marker(
#                 [56.331991, -4.609644],
#                 {}
#             ).addTo(map_529a1828d72ecd7268c7e512b1327211);
#
#
#             var icon_084ec5fa76ac860a68fdbf35cd9c7a1b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_504044c0721bd3a8d2712aa97c84ece6.setIcon(icon_084ec5fa76ac860a68fdbf35cd9c7a1b);
#
#
#         var popup_4551a864646dc86690d73608b90c93e9 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_69475b40aa2ed3759c29ab501bbe81bd = $(`&lt;div id=&quot;html_69475b40aa2ed3759c29ab501bbe81bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn a&#x27; Chroin&lt;/div&gt;`)[0];
#                 popup_4551a864646dc86690d73608b90c93e9.setContent(html_69475b40aa2ed3759c29ab501bbe81bd);
#
#
#
#         marker_504044c0721bd3a8d2712aa97c84ece6.bindPopup(popup_4551a864646dc86690d73608b90c93e9)
#         ;
#
#
#
#
#             var marker_0e13034da0c47c59be58c44a4acfeb28 = L.marker(
#                 [56.326686, -4.906709],
#                 {}
#             ).addTo(map_529a1828d72ecd7268c7e512b1327211);
#
#
#             var icon_661a4840a8034e0d61653c80df28b885 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e13034da0c47c59be58c44a4acfeb28.setIcon(icon_661a4840a8034e0d61653c80df28b885);
#
#
#         var popup_7cc84b488e10317e3f31840016445f88 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_6a2682259b5ddf1ef074afba3efcf0ad = $(`&lt;div id=&quot;html_6a2682259b5ddf1ef074afba3efcf0ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn Bhuidhe&lt;/div&gt;`)[0];
#                 popup_7cc84b488e10317e3f31840016445f88.setContent(html_6a2682259b5ddf1ef074afba3efcf0ad);
#
#
#
#         marker_0e13034da0c47c59be58c44a4acfeb28.bindPopup(popup_7cc84b488e10317e3f31840016445f88)
#         ;
#
#
#
#
#             var marker_dde74c3bd42574b35999db0cf58e2bf2 = L.marker(
#                 [56.325779, -4.641476],
#                 {}
#             ).addTo(map_529a1828d72ecd7268c7e512b1327211);
#
#
#             var icon_7e4114b20f9b0023bc9e2c0b5e254a4a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;

# %%
# save map
m.save("/Users/gordonwatt/code/dev/munro/output/freya.html")
