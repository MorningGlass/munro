# %%
# Script to show an individuals Climbed or Unclimbed Munros

import pandas as pd
import folium

# %%
# !pip show folium
# Out:
# Name: folium
# Version: 0.18.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: branca, jinja2, numpy, requests, xyzservices
# Required-by:

# %%
path_jo = '/Users/gordonwatt/code/dev/munro/data/Jo.csv'
path_gordon = '/Users/gordonwatt/code/dev/munro/data/Gordon.csv'
path_alan = '/Users/gordonwatt/code/dev/munro/data/Alan_Dunmur.csv'
path_ian = '/Users/gordonwatt/code/dev/munro/data/Ian_Sharp.csv'
path_iain = '/Users/gordonwatt/code/dev/munro/data/Iain_Young.csv'
path_freya = '/Users/gordonwatt/code/dev/munro/data/freya.csv'


# Load the CSV file
file1 = pd.read_csv(path_freya, encoding='utf-8')

# Drop rows where ascents = true (we only want unclimbed hills)
file1_all = file1
file1_remaining = file1[file1['Ascent'].isna()]
file1_climbed = file1[file1['Ascent'].notna()]

# Draw a map

# Create a map centered around the mean latitude and longitude
center_lat = file1_remaining['Latitude'].mean()
center_lon = file1_remaining['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# Add markers with name labels next to each point
for idx, row in file1_remaining.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='blue', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    
for idx, row in file1_climbed.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='green', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    

# Display the map in a Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d676cda54d423e2175b5face29e4fe7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d676cda54d423e2175b5face29e4fe7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d676cda54d423e2175b5face29e4fe7 = L.map(
#                 &quot;map_4d676cda54d423e2175b5face29e4fe7&quot;,
#                 {
#                     center: [57.00000611284046, -4.813177256809339],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afd4574c66431896233f6d1eb4d7445c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_afd4574c66431896233f6d1eb4d7445c.addTo(map_4d676cda54d423e2175b5face29e4fe7);
#
#
#             var marker_678bb10a6f1ac4c9dda66a8353b310b2 = L.marker(
#                 [56.870342, -4.199001],
#                 {}
#             ).addTo(map_4d676cda54d423e2175b5face29e4fe7);
#
#
#             var icon_af9a68eca5f85324ec97fed190722f41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_678bb10a6f1ac4c9dda66a8353b310b2.setIcon(icon_af9a68eca5f85324ec97fed190722f41);
#
#
#         var popup_ed3a0db32d050ff15d19b527b337a4d9 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_f3386b4c3fe7c563cc4ca8b7f6abd590 = $(`&lt;div id=&quot;html_f3386b4c3fe7c563cc4ca8b7f6abd590&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Bhuidheanach Bheag&lt;/div&gt;`)[0];
#                 popup_ed3a0db32d050ff15d19b527b337a4d9.setContent(html_f3386b4c3fe7c563cc4ca8b7f6abd590);
#
#
#
#         marker_678bb10a6f1ac4c9dda66a8353b310b2.bindPopup(popup_ed3a0db32d050ff15d19b527b337a4d9)
#         ;
#
#
#
#
#             var marker_3940e94097c7891a615aa8e75f3be0c3 = L.marker(
#                 [57.109564, -4.179285],
#                 {}
#             ).addTo(map_4d676cda54d423e2175b5face29e4fe7);
#
#
#             var icon_a1ace43a8d05c50984200a9e5dd7934b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3940e94097c7891a615aa8e75f3be0c3.setIcon(icon_a1ace43a8d05c50984200a9e5dd7934b);
#
#
#         var popup_251c3ffcc6762556623ca01f3b98d0df = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_992d52a50b6506899d000c1fbf6533c0 = $(`&lt;div id=&quot;html_992d52a50b6506899d000c1fbf6533c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Chailleach&lt;/div&gt;`)[0];
#                 popup_251c3ffcc6762556623ca01f3b98d0df.setContent(html_992d52a50b6506899d000c1fbf6533c0);
#
#
#
#         marker_3940e94097c7891a615aa8e75f3be0c3.bindPopup(popup_251c3ffcc6762556623ca01f3b98d0df)
#         ;
#
#
#
#
#             var marker_1bf078f9ac91305d933db44d2ab725b9 = L.marker(
#                 [57.693773, -5.128713],
#                 {}
#             ).addTo(map_4d676cda54d423e2175b5face29e4fe7);
#
#
#             var icon_21369e889f863ef8ce253c7eeb57e459 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1bf078f9ac91305d933db44d2ab725b9.setIcon(icon_21369e889f863ef8ce253c7eeb57e459);
#
#
#         var popup_5b51a0c10bbff1d0b580bd8639e97437 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_8aafcbaffc46e7a65266a557554f74bd = $(`&lt;div id=&quot;html_8aafcbaffc46e7a65266a557554f74bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&#x27; Chailleach&lt;/div&gt;`)[0];
#                 popup_5b51a0c10bbff1d0b580bd8639e97437.setContent(html_8aafcbaffc46e7a65266a557554f74bd);
#
#
#
#         marker_1bf078f9ac91305d933db44d2ab725b9.bindPopup(popup_5b51a0c10bbff1d0b580bd8639e97437)
#         ;
#
#
#
#
#             var marker_d01e41d9b304aa9d224738fc39a6b21d = L.marker(
#                 [57.184186, -5.154837],
#                 {}
#             ).addTo(map_4d676cda54d423e2175b5face29e4fe7);
#
#
#             var icon_894e89eaf33592bf738194ac6fde5c10 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;

# %%
# save map
m.save("/Users/gordonwatt/code/dev/munro/output/freya.html")
