# %%
# Script to show an individuals Climbed or Unclimbed Munros

import pandas as pd
import folium

# %%
# !pip show folium
# Out:
# Name: folium
# Version: 0.18.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: branca, jinja2, numpy, requests, xyzservices
# Required-by:

# %%
path_jo = '/Users/gordonwatt/code/dev/munro/data/Jo.csv'
path_gordon = '/Users/gordonwatt/code/dev/munro/data/Gordon.csv'
path_alan = '/Users/gordonwatt/code/dev/munro/data/Alan_Dunmur.csv'
path_ian = '/Users/gordonwatt/code/dev/munro/data/Ian_Sharp.csv'
path_iain = '/Users/gordonwatt/code/dev/munro/data/Iain_Young.csv'
path_freya = '/Users/gordonwatt/code/dev/munro/data/freya.csv'


# Load the CSV file
file1 = pd.read_csv(path_gordon, encoding='utf-8')

# Drop rows where ascents = true (we only want unclimbed hills)
file1_all = file1
file1_remaining = file1[file1['Ascent'].isna()]
file1_climbed = file1[file1['Ascent'].notna()]

# Draw a map

# Create a map centered around the mean latitude and longitude
center_lat = file1_remaining['Latitude'].mean()
center_lon = file1_remaining['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# Add markers with name labels next to each point
for idx, row in file1_remaining.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='blue', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    
for idx, row in file1_climbed.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='green', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    

# Display the map in a Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5c7761d03f8176f82e818005db8bd3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5c7761d03f8176f82e818005db8bd3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5c7761d03f8176f82e818005db8bd3f = L.map(
#                 &quot;map_d5c7761d03f8176f82e818005db8bd3f&quot;,
#                 {
#                     center: [56.94561889320388, -4.940373582524272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d30372533a0bc2657c09c212b120206 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5d30372533a0bc2657c09c212b120206.addTo(map_d5c7761d03f8176f82e818005db8bd3f);
#
#
#             var marker_4914c76b293c292314d21c9408c80825 = L.marker(
#                 [56.39023, -4.83563],
#                 {}
#             ).addTo(map_d5c7761d03f8176f82e818005db8bd3f);
#
#
#             var icon_d8a04d9ab42e7afc52f9e15af52be760 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4914c76b293c292314d21c9408c80825.setIcon(icon_d8a04d9ab42e7afc52f9e15af52be760);
#
#
#         var popup_eaef6b077611f96d8d9d729e06f26cc8 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_6bd8dc6536727c3b8ef4da143d55d21c = $(`&lt;div id=&quot;html_6bd8dc6536727c3b8ef4da143d55d21c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn a&#x27; Chleibh&lt;/div&gt;`)[0];
#                 popup_eaef6b077611f96d8d9d729e06f26cc8.setContent(html_6bd8dc6536727c3b8ef4da143d55d21c);
#
#
#
#         marker_4914c76b293c292314d21c9408c80825.bindPopup(popup_eaef6b077611f96d8d9d729e06f26cc8)
#         ;
#
#
#
#
#             var marker_30aeb005a1206bcaf80c7b5ca64c2096 = L.marker(
#                 [56.331991, -4.609644],
#                 {}
#             ).addTo(map_d5c7761d03f8176f82e818005db8bd3f);
#
#
#             var icon_9bee3842e3143a603c6e6b5a475a3fa7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_30aeb005a1206bcaf80c7b5ca64c2096.setIcon(icon_9bee3842e3143a603c6e6b5a475a3fa7);
#
#
#         var popup_ce95a3fcec6ba43a66f46f7a86b802f6 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_2a7a533e8e9168ac7b22ad2072405d53 = $(`&lt;div id=&quot;html_2a7a533e8e9168ac7b22ad2072405d53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn a&#x27; Chroin&lt;/div&gt;`)[0];
#                 popup_ce95a3fcec6ba43a66f46f7a86b802f6.setContent(html_2a7a533e8e9168ac7b22ad2072405d53);
#
#
#
#         marker_30aeb005a1206bcaf80c7b5ca64c2096.bindPopup(popup_ce95a3fcec6ba43a66f46f7a86b802f6)
#         ;
#
#
#
#
#             var marker_215b4cad1e7fda84b4940e582b34e7be = L.marker(
#                 [56.326686, -4.906709],
#                 {}
#             ).addTo(map_d5c7761d03f8176f82e818005db8bd3f);
#
#
#             var icon_20472f0da67f4842087b4385d40cf2e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_215b4cad1e7fda84b4940e582b34e7be.setIcon(icon_20472f0da67f4842087b4385d40cf2e9);
#
#
#         var popup_a770cf105de2258d25c8c57cd8ffa1f6 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_3eb64a6bd7201a81602cb4209b55b962 = $(`&lt;div id=&quot;html_3eb64a6bd7201a81602cb4209b55b962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn Bhuidhe&lt;/div&gt;`)[0];
#                 popup_a770cf105de2258d25c8c57cd8ffa1f6.setContent(html_3eb64a6bd7201a81602cb4209b55b962);
#
#
#
#         marker_215b4cad1e7fda84b4940e582b34e7be.bindPopup(popup_a770cf105de2258d25c8c57cd8ffa1f6)
#         ;
#
#
#
#
#             var marker_d6fbb325fdbf37670833669c38e71bc1 = L.marker(
#                 [56.325779, -4.641476],
#                 {}
#             ).addTo(map_d5c7761d03f8176f82e818005db8bd3f);
#
#
#             var icon_82c11a12975b51161041f1cd06ce34c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;

# %%
# save map
m.save("/Users/gordonwatt/code/dev/munro/output/grw.html")
