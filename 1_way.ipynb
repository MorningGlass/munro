# %%
# Script to show an individuals Climbed or Unclimbed Munros

import pandas as pd
import folium

# %%
# !pip show folium
# Out:
# Name: folium
# Version: 0.18.0
# Summary: Make beautiful maps with Leaflet.js & Python
# Home-page: https://github.com/python-visualization/folium
# Author: Rob Story
# Author-email: wrobstory@gmail.com
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages
# Requires: branca, jinja2, numpy, requests, xyzservices
# Required-by:

# %%
path_jo = '/Users/gordonwatt/code/dev/munro/v2/data/Jo.csv'
path_gordon = '/Users/gordonwatt/code/dev/munro/v2/data/Gordon.csv'
path_alan = '/Users/gordonwatt/code/dev/munro/v2/data/Alan_Dunmur.csv'
path_ian = '/Users/gordonwatt/code/dev/munro/v2/data/Ian_Sharp.csv'
path_iain = '/Users/gordonwatt/code/dev/munro/v2/data/Iain_Young.csv'
path_freya = '/Users/gordonwatt/code/dev/munro/v2/data/freya.csv'


# Load the CSV file
file1 = pd.read_csv(path_gordon, encoding='utf-8')

# Drop rows where ascents = true (we only want unclimbed hills)
file1_all = file1
file1_remaining = file1[file1['Ascent'].isna()]
file1_climbed = file1[file1['Ascent'].notna()]

# Draw a map

# Create a map centered around the mean latitude and longitude
center_lat = file1_remaining['Latitude'].mean()
center_lon = file1_remaining['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# Add markers with name labels next to each point
for idx, row in file1_remaining.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='blue', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    
for idx, row in file1_climbed.iterrows():
    # Customize marker icon and color
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(row['Name'], min_width = 100, max_width = 200),# Display the name when clicked
        # tooltip=row['Name'],  # Display the name on hover
        icon=folium.Icon(color='green', icon='info-sign')  # Customize icon color and style
    ).add_to(m)
    

# Display the map in a Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79db4021712866eda70df95ccc5b629c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79db4021712866eda70df95ccc5b629c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79db4021712866eda70df95ccc5b629c = L.map(
#                 &quot;map_79db4021712866eda70df95ccc5b629c&quot;,
#                 {
#                     center: [56.94561889320388, -4.940373582524272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8b5aa309be5b8fbd7a71ad07c016209 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d8b5aa309be5b8fbd7a71ad07c016209.addTo(map_79db4021712866eda70df95ccc5b629c);
#
#
#             var marker_59a1a7837bc070ee50b8a7e95d623881 = L.marker(
#                 [56.39023, -4.83563],
#                 {}
#             ).addTo(map_79db4021712866eda70df95ccc5b629c);
#
#
#             var icon_f578e5698d9dd8172303e35cf4313d23 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_59a1a7837bc070ee50b8a7e95d623881.setIcon(icon_f578e5698d9dd8172303e35cf4313d23);
#
#
#         var popup_2d3d79aaaf8134eeac124474d4e78208 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_d9440e906b0b97fcfeea04d581cd237a = $(`&lt;div id=&quot;html_d9440e906b0b97fcfeea04d581cd237a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn a&#x27; Chleibh&lt;/div&gt;`)[0];
#                 popup_2d3d79aaaf8134eeac124474d4e78208.setContent(html_d9440e906b0b97fcfeea04d581cd237a);
#
#
#
#         marker_59a1a7837bc070ee50b8a7e95d623881.bindPopup(popup_2d3d79aaaf8134eeac124474d4e78208)
#         ;
#
#
#
#
#             var marker_73ecb8446ab0c1bf949ac212915ba417 = L.marker(
#                 [56.331991, -4.609644],
#                 {}
#             ).addTo(map_79db4021712866eda70df95ccc5b629c);
#
#
#             var icon_8c950b6180c872067293756a3e5afe5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_73ecb8446ab0c1bf949ac212915ba417.setIcon(icon_8c950b6180c872067293756a3e5afe5c);
#
#
#         var popup_068eba514e85290b44450a3bf4f429f6 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_7c3c9abefad825019866e33c4f1c131c = $(`&lt;div id=&quot;html_7c3c9abefad825019866e33c4f1c131c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn a&#x27; Chroin&lt;/div&gt;`)[0];
#                 popup_068eba514e85290b44450a3bf4f429f6.setContent(html_7c3c9abefad825019866e33c4f1c131c);
#
#
#
#         marker_73ecb8446ab0c1bf949ac212915ba417.bindPopup(popup_068eba514e85290b44450a3bf4f429f6)
#         ;
#
#
#
#
#             var marker_ef4d6d16083cfb705e8bbbd50a56adc4 = L.marker(
#                 [56.326686, -4.906709],
#                 {}
#             ).addTo(map_79db4021712866eda70df95ccc5b629c);
#
#
#             var icon_4f0cb175e9e8a971edfd77413fb15f5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef4d6d16083cfb705e8bbbd50a56adc4.setIcon(icon_4f0cb175e9e8a971edfd77413fb15f5c);
#
#
#         var popup_46088dbd0615c86d553ad040f02a4554 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 100});
#
#
#
#                 var html_3f5dd878e189a069f9d16dd1b97ffb34 = $(`&lt;div id=&quot;html_3f5dd878e189a069f9d16dd1b97ffb34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beinn Bhuidhe&lt;/div&gt;`)[0];
#                 popup_46088dbd0615c86d553ad040f02a4554.setContent(html_3f5dd878e189a069f9d16dd1b97ffb34);
#
#
#
#         marker_ef4d6d16083cfb705e8bbbd50a56adc4.bindPopup(popup_46088dbd0615c86d553ad040f02a4554)
#         ;
#
#
#
#
#             var marker_958eb1baa03e753be178f74ca9866101 = L.marker(
#                 [56.325779, -4.641476],
#                 {}
#             ).addTo(map_79db4021712866eda70df95ccc5b629c);
#
#
#             var icon_ca87abc8b15a00030e9e22442eb45e33 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;

# %%
# save map
m.save("/Users/gordonwatt/code/dev/morningglass.github.io/data/grw.html")
